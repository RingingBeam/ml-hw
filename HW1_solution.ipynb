# %% [markdown]
# <span style="font-size: 14pt">MIPT, Advanced ML, Autumn 2017</span>
#
# <span style="font-size: 16pt"> HW#1 </span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Лукишн Ю.П. Адаптивные методы краткосрочного прогнозирования временных рядов. Финансы и статистика. 2003, главы 1,4,5,7.
# - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_Aut_fall 401 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер>.ipnb``, к примеру -- ``ivanov_401_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_Aut_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Мы используем автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Напоминаем, что дедлайны жесткие, письма пришедшие после автоматически удаляются =( чтобы соблазна не было

# %% [markdown]
# <h1 align="center">Check Questions (15%)</h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: Опишите, как изменяется адаптивная способность алгоритма ЭСС при изменении параметра $\alpha$ от 0 до 1.
#
# <Ответ>
# $S_t$ = $\alpha$$y_t$ + (1-$\alpha$)$S_{t-1}$
#
# Сглаживающий парметр $\alpha$ влияет на скорость уменьшения веса прошлых наблюдений и, соответственно, влияние их на текущий уровень. Чем больше значение параметра, тем больше будет влияние последних уровней, и наоборот, чем меньше его значение, тем больше будет воздействие экспоненциальной средней, таким образом, пргноз получается более плавным.
#
#
# **Вопрос 2**: Каким следует выбрать параметр сглаживания тренда $\alpha_2$ в модели Хольта (линейный тренд) в случае, когда вы предсказываете временной ряд 1) с плавно меняющимя трендом; 2) стохастически меняющися трендом?
#
# <Ответ>
# Параметр $\alpha_2$ здесь будет эквивалентен параметру $\alpha$ из предыдущего вопроса. Таким образом, в первом случае мы берем маленький параметр $\alpha$, для того, чтобы тренд менялся более плавно, а во втором-большой параметр, чтобы прогноз реагировал на изменения.
#
#
#
# **Вопрос 3**: Докажите  эквивалетность формул расчёта (в рекуррентной форме и в форме корректировки прогноза (correction error form) )скрытых компонент временного ряда в модели Тейла-Вейджа (период сезонность обозначается $p$):
# $$l_t = \alpha (y_t - s_{t-p}) + (1-\alpha) (l_{t-1} + b_{t-1} ) \color{red}{=} l_{t-1} + b_{t-1} + \alpha e_t;$$,
#     $$ b_t = \beta (l_{t} - l_{t-1} ) + (1-\beta) b_{t-1} \color{red}{=} b_{t-1} + \alpha\beta e_t;$$,
#     $$ s_t = \gamma (y_t-l_t) + (1-\gamma) s_{t-p} \color{red}{=} s_{t-p} + \gamma(1-\alpha)e_t.$$,
#
# <Ответ>
# $e_t$ = $y_t - s_{t-p} - l_{t-p} - b_{t-1}$
#
# $l_t$ = $\alpha$ $(y_t - s_{t-p})$ +$(1-\alpha)(l_{t-1}+b_{t-1})$ = $l_{t-1} +b_{t-1}$ + $\alpha$$(y_t - s_{t-p}) -l_{t-1} - b_{t-1})$ = $l_{t-1} + b_{t-1}$ +$\alpha$$e_t$
#
# $b_t$ = $\beta$$(l_t - l_{t-1}) + (1-\beta)b_{t-1}$ = $b_{t-1}$ + $\beta(b_{t-1}$ + $\alpha$$e_t$) - $\beta$$b_{t-1} = b_{t-1}$ + $\alpha$$\beta$$e_t$
#
# $s_t$ = $\gamma(y_t - l_t) + (1-\gamma)s_{t-p} = s_{t-p} + \gamma(y_t - l_t - s_{t-p}) = s_{t-p} + \gamma(e_t+l_{t-1}+b_{t-1}-l_t) = s_{t-p} +\gamma(e_t-\alpha\ e_t) = s_{t-p}+\gamma(1-\alpha)e_t$
#
#
#
# **Вопрос 4**: Выведите формулу расчёта скрытых компонент в форме корректировки прогноза (correction error form) временного ряда в модели ЭС с линейным затухающим трендом (WS with additive damped trend):
#
# $$\hat{y}_{t+d|t} = l_t + \left(\phi + \phi^2 + \dots + \phi^{d}\right) b_t.$$,
#
# Скрытые компоненты ВР согласно модели в рекуррентной форме записываются:
#     $$ l_{t}       = \alpha y_t + \left(1-\alpha\right) \left(l_{t-1} +\phi b_{t-1}\right),$$,
#     $$ b_t         = \beta \left(l_t - l_{t-1}\right) + \left(1-\beta\right)\phi b_{t-1}.$$
#
#
# <Ответ>
# $e_t$ = $y_t$ - $l_{t-1}$ - $\phi$$b_t$
#
# $l_t$ = $\alpha$$y_t + (1-\alpha)$($l_{t-1}$ +$\phi$$b_{t-1}) = l_{t-1}$ + $\phi$$b_{t-1} + \alpha(y_t - l_{t-1}$ - $\phi$$b_{t-1} = l_{t-1}$+$\phi$$b_{t-1}$+$\alpha$$e_t$
#
# $b_t$ = $\beta$$(l_t-l_{t-1})+(1-\beta$)$\phi$$b_{t-1} = \beta$($\phi$$b_{t-1}$+$\alpha$$e_t)+(1-\beta$)$\phi$$b_{t-1} = \phi$$b_{t-1}+\beta(\phi$$b_{t-1}+\alpha$$e_t-\phi$$b_{t-1})=\phi$$b_{t-1}+\beta$$\alpha$$e_t$
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# <h1 align="center"> Practice</h1>
# #  1. reading data (5%)
#
#   * Download data for following data sets
#      - 1) <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv </span>(1 TS of monthly wage in Russia)

# %%
# start with this code
import pandas as pd
import numpy as np
from utils import InitExponentialSmoothing, BuildForecast, plotTSForecast
from utils import qualityRMSE, qualityMedianAE, qualityMACAPE, qualitySSE, qualityMSE, qualityMAPE 
import math

# %matplotlib inline


wage = pd.read_csv('monthly-wage.csv', sep=';', decimal='.', index_col=0, parse_dates=True, dayfirst=True)

# Put your code below
wage.plot(figsize=(15,5))

# %% [markdown]
# # 2. Build the Forecast with  IES (5%)
#
# You need to apply IES model (see seminar 1) for the TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
#
# * 0) Forecast Wage TS with SES $\alpha=.1$.
# * 1) Find the best param $\alpha$ of SES for data period from 09.1998 to 01.2015. Is the optimal value close to 0 or 1? (You
# can choose any loss function above).
# * 2) Draw the forecast that correspond to IES with optimial value $\alpha$ (use time steps from 09.1998 to 01.2017.)
#      Conclude whether IES can be used for this TS? If can not than explain why.
# * 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]. (You can choose any Loss function from seminar 1).

# %% [markdown]
# ## 1) Search for the optimal $\alpha$

# %%
ALPHA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
ESParamsArray = [{'alpha':alpha, 'AdaptationPeriod':5} for alpha in ALPHA]
FRC_WAGE = BuildForecast(h=1, ts=wage.loc['1998-09-01':'2017-01-01'], AlgName =  'InitExponentialSmoothing', AlgTitle='IES',ParamsArray = ESParamsArray)

# %%
# compare ES parameters
QualityStr = pd.DataFrame(index = wage.columns, columns = FRC_WAGE.keys())
indx = wage.loc['1998-09-01':'2015-01-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = FRC_WAGE[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[indx], frc_wage.loc[indx])
QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# IES {'alpha': 0.4, 'AdaptationPeriod': 5}     0.056082
# IES {'alpha': 0.3, 'AdaptationPeriod': 5}     0.056430
# IES {'alpha': 0.5, 'AdaptationPeriod': 5}     0.057288
# IES {'alpha': 0.7, 'AdaptationPeriod': 5}     0.060144
# IES {'alpha': 0.2, 'AdaptationPeriod': 5}     0.060185
# IES {'alpha': 0.8, 'AdaptationPeriod': 5}     0.061082
# IES {'alpha': 0.9, 'AdaptationPeriod': 5}     0.061551
# IES {'alpha': 0.99, 'AdaptationPeriod': 5}    0.062160
# IES {'alpha': 0.1, 'AdaptationPeriod': 5}     0.082017
# IES {'alpha': 0.01, 'AdaptationPeriod': 5}    0.402981
# dtype: float64

# %% [markdown]
# ## 2) draw the forecast with optimial value $\alpha $

# %%
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plotTSForecast(wage.loc['1998-09-01':'2017-01-01'], FRC_WAGE[algName].loc['1998-09-01':'2017-01-01'], ts_num=0, alg_title='IES')

# %% [markdown]
# Этот прогноз плохо подходит, т.к. не отображает сезонность, имеющуюся в данных.

# %% [markdown]
# ## 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]

# %%
qualityMACAPE(wage.loc['2015-02-01':'2017-01-01'], FRC_WAGE[algName].loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.062764
# dtype: float64

# %% [markdown]
# # 3. Winters model for Additive Seasonality (25%)
# You need to realize ES model for TS with additive seasonality and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Winters model for Seasonal TS
# * 2) Find optimal params $\alpha$ (smoothing of level) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw the forecast that correspond optimal values $\alpha$ and $\gamma$ (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of IES: is it better?
# * 5) Conclude whether Winter's ES can be used for this TS?

# %%
# Start with this code
###################### Winters Exponential Smoothing #########################
# x <array Tx1>- time series, 
# h <scalar> - forecasting delay
# Params <dict> - dictionary with 
#    alpha <scalar in [0,1]> - smoothing parameter
#    delts <scalar in [0,1]> - seasonality smoothing parameter

def WintersExponentialSmoothing(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    delta = Params['delta']
    p = Params['seasonality_period']    
    FORECAST = np.zeros(T)      ## put foreast of the model here   
    l= x[0] # initialize ts level 
    s= x[:p] - x[0]*np.ones(p)    # initalize seasonality values (it must be vector of lenth p)
    for cntr in range(T):
        if not math.isnan(x[cntr]):
            if math.isnan(l):
                l= x[cntr]  # initialize 
            if math.isnan(s[cntr % p]):
                s[cntr % p]= 0 # initialize 
            const = x[cntr] - l - s[cntr%p]
            l = l + alpha*const
            s[cntr % p] = s[cntr % p] + delta*(1-alpha)*const        
        FORECAST[cntr] = l + s[cntr%p]
    return FORECAST

# %%
# Put your code here
ts = wage.loc['1998-09-01':'2015-01-01']
ALPHA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
DELTA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
WParams = [{'alpha':alpha, 'delta':delta, 'seasonality_period':12 } for alpha in ALPHA for delta in DELTA]

# %%
QualityStr = pd.DataFrame(index = ts.columns, columns =[str(i) for i in WParams])
indx = ts.index
for param_cntr in WParams:
    frc_wage = pd.DataFrame(WintersExponentialSmoothing(ts['Real wage'], 1, param_cntr), columns = ts.columns, index = indx)    
    QualityStr[str(param_cntr)],_ = qualityMACAPE(ts, frc_wage.loc[indx])
QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# {'alpha': 0.99, 'delta': 0.99, 'seasonality_period': 12}    0.000004
# {'alpha': 0.9, 'delta': 0.99, 'seasonality_period': 12}     0.000029
# {'alpha': 0.99, 'delta': 0.9, 'seasonality_period': 12}     0.000042
# {'alpha': 0.8, 'delta': 0.99, 'seasonality_period': 12}     0.000045
# {'alpha': 0.7, 'delta': 0.99, 'seasonality_period': 12}     0.000060
# {'alpha': 0.99, 'delta': 0.8, 'seasonality_period': 12}     0.000083
# {'alpha': 0.5, 'delta': 0.99, 'seasonality_period': 12}     0.000104
# {'alpha': 0.99, 'delta': 0.7, 'seasonality_period': 12}     0.000126
# {'alpha': 0.4, 'delta': 0.99, 'seasonality_period': 12}     0.000136
# {'alpha': 0.3, 'delta': 0.99, 'seasonality_period': 12}     0.000185
# {'alpha': 0.99, 'delta': 0.5, 'seasonality_period': 12}     0.000211
# {'alpha': 0.99, 'delta': 0.4, 'seasonality_period': 12}     0.000255
# {'alpha': 0.2, 'delta': 0.99, 'seasonality_period': 12}     0.000266
# {'alpha': 0.99, 'delta': 0.3, 'seasonality_period': 12}     0.000298
# {'alpha': 0.9, 'delta': 0.9, 'seasonality_period': 12}      0.000299
# {'alpha': 0.99, 'delta': 0.2, 'seasonality_period': 12}     0.000343
# {'alpha': 0.99, 'delta': 0.1, 'seasonality_period': 12}     0.000387
# {'alpha': 0.1, 'delta': 0.99, 'seasonality_period': 12}     0.000426
# {'alpha': 0.99, 'delta': 0.01, 'seasonality_period': 12}    0.000428
# {'alpha': 0.8, 'delta': 0.9, 'seasonality_period': 12}      0.000465
# {'alpha': 0.9, 'delta': 0.8, 'seasonality_period': 12}      0.000619
# {'alpha': 0.7, 'delta': 0.9, 'seasonality_period': 12}      0.000620
# {'alpha': 0.01, 'delta': 0.99, 'seasonality_period': 12}    0.000809
# {'alpha': 0.9, 'delta': 0.7, 'seasonality_period': 12}      0.000961
# {'alpha': 0.8, 'delta': 0.8, 'seasonality_period': 12}      0.000969
# {'alpha': 0.5, 'delta': 0.9, 'seasonality_period': 12}      0.001045
# {'alpha': 0.7, 'delta': 0.8, 'seasonality_period': 12}      0.001283
# {'alpha': 0.4, 'delta': 0.9, 'seasonality_period': 12}      0.001370
# {'alpha': 0.8, 'delta': 0.7, 'seasonality_period': 12}      0.001518
# {'alpha': 0.9, 'delta': 0.5, 'seasonality_period': 12}      0.001722
#                                                               ...
# {'alpha': 0.1, 'delta': 0.7, 'seasonality_period': 12}      0.013930
# {'alpha': 0.4, 'delta': 0.2, 'seasonality_period': 12}      0.014043
# {'alpha': 0.2, 'delta': 0.5, 'seasonality_period': 12}      0.014370
# {'alpha': 0.5, 'delta': 0.1, 'seasonality_period': 12}      0.014594
# {'alpha': 0.3, 'delta': 0.3, 'seasonality_period': 12}      0.014752
# {'alpha': 0.2, 'delta': 0.4, 'seasonality_period': 12}      0.017698
# {'alpha': 0.4, 'delta': 0.1, 'seasonality_period': 12}      0.017701
# {'alpha': 0.3, 'delta': 0.2, 'seasonality_period': 12}      0.018120
# {'alpha': 0.01, 'delta': 0.8, 'seasonality_period': 12}     0.018703
# {'alpha': 0.5, 'delta': 0.01, 'seasonality_period': 12}     0.018730
# {'alpha': 0.2, 'delta': 0.3, 'seasonality_period': 12}      0.021291
# {'alpha': 0.3, 'delta': 0.1, 'seasonality_period': 12}      0.022549
# {'alpha': 0.4, 'delta': 0.01, 'seasonality_period': 12}     0.022687
# {'alpha': 0.1, 'delta': 0.5, 'seasonality_period': 12}      0.025088
# {'alpha': 0.2, 'delta': 0.2, 'seasonality_period': 12}      0.025554
# {'alpha': 0.3, 'delta': 0.01, 'seasonality_period': 12}     0.028372
# {'alpha': 0.01, 'delta': 0.7, 'seasonality_period': 12}     0.030833
# {'alpha': 0.2, 'delta': 0.1, 'seasonality_period': 12}      0.031252
# {'alpha': 0.1, 'delta': 0.4, 'seasonality_period': 12}      0.031426
# {'alpha': 0.1, 'delta': 0.3, 'seasonality_period': 12}      0.038372
# {'alpha': 0.2, 'delta': 0.01, 'seasonality_period': 12}     0.038409
# {'alpha': 0.1, 'delta': 0.2, 'seasonality_period': 12}      0.046264
# {'alpha': 0.1, 'delta': 0.1, 'seasonality_period': 12}      0.055510
# {'alpha': 0.01, 'delta': 0.5, 'seasonality_period': 12}     0.065559
# {'alpha': 0.1, 'delta': 0.01, 'seasonality_period': 12}     0.066179
# {'alpha': 0.01, 'delta': 0.4, 'seasonality_period': 12}     0.091468
# {'alpha': 0.01, 'delta': 0.3, 'seasonality_period': 12}     0.127400
# {'alpha': 0.01, 'delta': 0.2, 'seasonality_period': 12}     0.180545
# {'alpha': 0.01, 'delta': 0.1, 'seasonality_period': 12}     0.265422
# {'alpha': 0.01, 'delta': 0.01, 'seasonality_period': 12}    0.397450
# Length: 100, dtype: float64

# %%
ts = wage.loc['1998-09-01':'2017-01-01']
params = eval(QualityStr.columns[0])
frc = pd.DataFrame(WintersExponentialSmoothing(ts['Real wage'], 1, params), columns = [''], index = ts.index)
plotTSForecast(ts, frc, ts_num=0, alg_title='Winters')

# %%
frc.columns = ts.columns
qualityMACAPE(ts.loc['2015-02-01':'2017-01-01'], frc.loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.000005
# dtype: float64

# %% [markdown]
# Эта модель имеет меньшую ошибку, и судя по графику, очень хорошо предсказывает

# %% [markdown]
# # 4. Theil-Wage model for TS with linear trend and seasonality (25%)
# You need to realize Theil-Wage model and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize Theil-Wage model for
# * 2) Find optimal params $\alpha$ (smoothing of level), $\beta$ (smoothing trend) and $\gamma$ (smoothing of seasonality) (use data from 09.1998 to 01.2015).(Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values $\alpha$, $\beta$ and $\gamma$ from 09.1998 to 01.2017.
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model: is it better than the last one?
# * \*5) Suggest how can the Theil-Wage model be improved to make accuracy of forecast better?

# %%
# Put your code here
def Theil_Wage(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    beta = Params['beta']
    gamma = Params['gamma']
    p = Params['seasonality_period']    
    FORECAST = np.zeros(T)    
    l = x[0]
    b = 0
    s = np.array([np.NaN for i in range(p)])    
    for cntr in np.arange(1,T):
        if not math.isnan(x[cntr]):
            if math.isnan(l):
                l= x[cntr] 
            if math.isnan(s[cntr % p]):
                s[cntr % p]= x[cntr] - l - b        
            const = x[cntr] - l - s[cntr%p] - b
            l = l + b + alpha*const
            b = b + alpha*beta*const
            s[cntr % p] = s[cntr % p] + gamma*(1-alpha)*const          
        FORECAST[cntr] = l + b + s[(cntr)%p]
    return FORECAST

# %%
ts = wage.loc['1998-09-01':'2015-01-01']
ALPHA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
BETA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
DELTA = [.99, .9, .8, .7, .5, .4, .3, .2, .1, .01]
WParams = [{'alpha':alpha, 'beta': beta, 'gamma':delta, 'seasonality_period':12 } for alpha in ALPHA for delta in DELTA for beta in BETA]

# %%
QualityStr = pd.DataFrame(index = ts.columns, columns =[str(i) for i in WParams])
indx = ts.index
for param_cntr in WParams:
    frc_wage = pd.DataFrame(Theil_Wage(ts['Real wage'], 1, param_cntr), columns = ts.columns, index = indx)  
    QualityStr[str(param_cntr)],_ = qualityMACAPE(ts, frc_wage.loc[indx])
QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}     -1.594974
# {'alpha': 0.1, 'beta': 0.99, 'gamma': 0.99, 'seasonality_period': 12}    -0.369966
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.99, 'seasonality_period': 12}     -0.260474
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}    0.010731
# {'alpha': 0.1, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.012269
# {'alpha': 0.2, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.012879
# {'alpha': 0.2, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.012882
# {'alpha': 0.3, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013034
# {'alpha': 0.3, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013144
# {'alpha': 0.4, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013187
# {'alpha': 0.1, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013224
# {'alpha': 0.4, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013291
# {'alpha': 0.5, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013313
# {'alpha': 0.01, 'beta': 0.1, 'gamma': 0.99, 'seasonality_period': 12}     0.013341
# {'alpha': 0.5, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013383
# {'alpha': 0.7, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013456
# {'alpha': 0.7, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013495
# {'alpha': 0.8, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013499
# {'alpha': 0.8, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013530
# {'alpha': 0.9, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}      0.013541
# {'alpha': 0.9, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}      0.013542
# {'alpha': 0.9, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}     0.013554
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}     0.013563
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}     0.013563
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}    0.013563
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.7, 'seasonality_period': 12}     0.013563
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.5, 'seasonality_period': 12}     0.013564
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.4, 'seasonality_period': 12}     0.013564
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.3, 'seasonality_period': 12}     0.013565
# {'alpha': 0.99, 'beta': 0.01, 'gamma': 0.2, 'seasonality_period': 12}     0.013565
#                                                                             ...
# {'alpha': 0.01, 'beta': 0.7, 'gamma': 0.01, 'seasonality_period': 12}     0.102143
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.7, 'seasonality_period': 12}       0.110194
# {'alpha': 0.3, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}       0.113477
# {'alpha': 0.01, 'beta': 0.1, 'gamma': 0.1, 'seasonality_period': 12}      0.118504
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.3, 'seasonality_period': 12}     0.119769
# {'alpha': 0.2, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}       0.119782
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.7, 'seasonality_period': 12}      0.123796
# {'alpha': 0.3, 'beta': 0.8, 'gamma': 0.8, 'seasonality_period': 12}       0.128449
# {'alpha': 0.1, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}      0.143004
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.8, 'seasonality_period': 12}       0.151123
# {'alpha': 0.01, 'beta': 0.1, 'gamma': 0.01, 'seasonality_period': 12}     0.152084
# {'alpha': 0.1, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}      0.156562
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.2, 'seasonality_period': 12}     0.162200
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.7, 'seasonality_period': 12}       0.168201
# {'alpha': 0.3, 'beta': 0.7, 'gamma': 0.99, 'seasonality_period': 12}      0.176935
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}       0.180641
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.8, 'seasonality_period': 12}      0.209167
# {'alpha': 0.3, 'beta': 0.8, 'gamma': 0.9, 'seasonality_period': 12}       0.222103
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.1, 'seasonality_period': 12}     0.227237
# {'alpha': 0.2, 'beta': 0.7, 'gamma': 0.99, 'seasonality_period': 12}      0.230335
# {'alpha': 0.3, 'beta': 0.8, 'gamma': 0.99, 'seasonality_period': 12}      0.253426
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.01, 'seasonality_period': 12}    0.323377
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.7, 'seasonality_period': 12}      0.345781
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.9, 'seasonality_period': 12}       0.374469
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}      0.530510
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.9, 'seasonality_period': 12}       0.557032
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.9, 'seasonality_period': 12}       0.670218
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}       0.699886
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}      2.279046
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}      2.597765
# Length: 1000, dtype: float64

# %%
ts = wage.loc['1998-09-01':'2017-01-01']
params = eval(QualityStr.columns[0])
frc = pd.DataFrame(Theil_Wage(ts['Real wage'], 1, params), columns = [''], index = ts.index)
plotTSForecast(ts, frc, ts_num=0, alg_title='Winters')

# %%
frc.columns = ts.columns
qualityMACAPE(ts.loc['2015-02-01':'2017-01-01'], frc.loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.049211
# dtype: float64

# %% [markdown]
# Эта модель хуже второй, но лучше первой

# %% [markdown]
# # 5. Non-additive model of ES (25%)
# You need to realize some ES-model that include non-addive component (or multiplicative trend or multiplicative component) and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
# * 1) Realize one of following ES models: ESM(A,M) (t.e. Holt-Winters model), ESM(Ad,M), ESM(M,A), ESM(M,M) model.
# * 2) Find optimal params of the model (use data from 09.1998 to 01.2015). Note: if you choose damped trend model that $\phi$ you can just set it by expert opinion (say $0.98$). (Loss function should be the same as in task 2.)
# * 3) Draw forecast with optimal values of it's params (data from 09.1998 to 01.2017).
# * 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (Loss function should be the same as in task 2.). Compare it with accuracy of Winters model and Theil-Wage model: is it better than the last one?
# * 5) Is it true that multiplicative model are more unstable than additive? Unstable means thet forecast is can diveret

# %%
# HW
def Non_add(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    beta = Params['beta']
    gamma = Params['gamma']
    p = Params['seasonality_period']    
    FORECAST = np.zeros(T)   
    l = x[0]
    b = 0
    s = np.array([np.NaN for i in range(p)])   
    for cntr in np.arange(1,T):
        if not math.isnan(x[cntr]):
            if math.isnan(l):
                l= x[cntr] 
            if math.isnan(s[cntr % p]):
                s[cntr % p]= x[cntr] / (l + b)          
            const = x[cntr] / s[cntr%p] - b - l
            l = l + b + alpha*const
            b = b + alpha*beta*const
            s[cntr % p] = s[cntr % p] + gamma*(1-alpha)*const*s[cntr % p]/l
        FORECAST[cntr] = (l + b) * s[(cntr)%p]
    return FORECAST

# %%
ts = wage.loc['1998-09-01':'2015-01-01']
WParams = [{'alpha':alpha, 'beta': beta, 'gamma':delta, 'seasonality_period':12 } for alpha in ALPHA for delta in DELTA for beta in BETA]

# %%
QualityStr = pd.DataFrame(index = ts.columns, columns =[str(i) for i in WParams])
indx = ts.index
for param_cntr in WParams:
    frc_wage = pd.DataFrame(Non_add(ts['Real wage'], 1, param_cntr), columns = ts.columns, index = indx)    
    QualityStr[str(param_cntr)],_ = qualityMACAPE(ts, frc_wage.loc[indx])
QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.4, 'seasonality_period': 12}       -3.033976
# {'alpha': 0.5, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}        -2.330585
# {'alpha': 0.4, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}        -1.247904
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.7, 'seasonality_period': 12}        -0.437662
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.9, 'seasonality_period': 12}        -0.319090
# {'alpha': 0.4, 'beta': 0.9, 'gamma': 0.7, 'seasonality_period': 12}        -0.276456
# {'alpha': 0.1, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}       -0.208232
# {'alpha': 0.1, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}       -0.155569
# {'alpha': 0.4, 'beta': 0.8, 'gamma': 0.7, 'seasonality_period': 12}        -0.056740
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}       -0.047285
# {'alpha': 0.4, 'beta': 0.5, 'gamma': 0.9, 'seasonality_period': 12}         0.008058
# {'alpha': 0.01, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}      0.010825
# {'alpha': 0.1, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.012593
# {'alpha': 0.2, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.012936
# {'alpha': 0.2, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.013060
# {'alpha': 0.3, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013072
# {'alpha': 0.1, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013235
# {'alpha': 0.4, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013243
# {'alpha': 0.3, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.013255
# {'alpha': 0.5, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013350
# {'alpha': 0.4, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.013360
# {'alpha': 0.5, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.013427
# {'alpha': 0.7, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013467
# {'alpha': 0.8, 'beta': 0.01, 'gamma': 0.9, 'seasonality_period': 12}        0.013493
# {'alpha': 0.4, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}        0.013494
# {'alpha': 0.8, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}        0.013505
# {'alpha': 0.9, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}        0.013506
# {'alpha': 0.7, 'beta': 0.01, 'gamma': 0.99, 'seasonality_period': 12}       0.013509
# {'alpha': 0.5, 'beta': 0.01, 'gamma': 0.8, 'seasonality_period': 12}        0.013512
# {'alpha': 0.9, 'beta': 0.01, 'gamma': 0.7, 'seasonality_period': 12}        0.013515
#                                                                              ...
# {'alpha': 0.1, 'beta': 0.99, 'gamma': 0.99, 'seasonality_period': 12}       0.406731
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.5, 'seasonality_period': 12}        0.407771
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.7, 'seasonality_period': 12}        0.431055
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.9, 'seasonality_period': 12}         0.436701
# {'alpha': 0.4, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}        0.437214
# {'alpha': 0.4, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}         0.437941
# {'alpha': 0.3, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}         0.445445
# {'alpha': 0.2, 'beta': 0.7, 'gamma': 0.99, 'seasonality_period': 12}        0.451996
# {'alpha': 0.2, 'beta': 0.8, 'gamma': 0.8, 'seasonality_period': 12}         0.470241
# {'alpha': 0.5, 'beta': 0.8, 'gamma': 0.99, 'seasonality_period': 12}        0.494597
# {'alpha': 0.4, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}        0.509668
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}         0.519322
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.5, 'seasonality_period': 12}         0.545950
# {'alpha': 0.5, 'beta': 0.8, 'gamma': 0.9, 'seasonality_period': 12}         0.614643
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.9, 'seasonality_period': 12}        0.641380
# {'alpha': 0.2, 'beta': 0.99, 'gamma': 0.8, 'seasonality_period': 12}        0.649575
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.9, 'seasonality_period': 12}         0.657596
# {'alpha': 0.4, 'beta': 0.99, 'gamma': 0.7, 'seasonality_period': 12}        0.662163
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}        0.666108
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.7, 'seasonality_period': 12}        0.880324
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.8, 'seasonality_period': 12}         0.994191
# {'alpha': 0.5, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}         1.025794
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.8, 'seasonality_period': 12}        1.044096
# {'alpha': 0.3, 'beta': 0.99, 'gamma': 0.5, 'seasonality_period': 12}        1.263197
# {'alpha': 0.3, 'beta': 0.9, 'gamma': 0.7, 'seasonality_period': 12}         1.359632
# {'alpha': 0.3, 'beta': 0.8, 'gamma': 0.9, 'seasonality_period': 12}         1.379720
# {'alpha': 0.2, 'beta': 0.9, 'gamma': 0.99, 'seasonality_period': 12}        1.398961
# {'alpha': 0.2, 'beta': 0.7, 'gamma': 0.9, 'seasonality_period': 12}         3.493689
# {'alpha': 0.3, 'beta': 0.5, 'gamma': 0.99, 'seasonality_period': 12}        5.259569
# {'alpha': 0.4, 'beta': 0.9, 'gamma': 0.9, 'seasonality_period': 12}       189.221627
# Length: 1000, dtype: float64

# %%
ts = wage.loc['1998-09-01':'2017-01-01']
params = eval(QualityStr.columns[0])
frc = pd.DataFrame(Non_add(ts['Real wage'], 1, params), columns = [''], index = ts.index)
plotTSForecast(ts, frc, ts_num=0, alg_title='Winters')

# %%
frc.columns = ts.columns
qualityMACAPE(ts.loc['2015-02-01':'2017-01-01'], frc.loc['2015-02-01':'2017-01-01'])[0]
# Out:
# Real wage    0.038263
# dtype: float64

# %% [markdown]
# Хуже остальных, кроме первой, моделей. В отличие от аддитивных моделей, менее стабильная (видно из графика, особенно конечной его части)
# Лучше всего оказалась вторая модель.
